# %% [markdown]
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/75165824-badf4680-5701-11ea-9c5b-5475b0a33abf.png"
#     style="width:300px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Pandas DataFrame: Two-dimensional labeled data structure
#
# Probably the most important data structure of pandas is the `DataFrame`. It's a tabular structure tightly integrated with `Series`.
#
# A **Pandas DataFrame** is the primary data structure in the Pandas library, representing a **two-dimensional labeled table** with columns of potentially different data types (similar to a spreadsheet or SQL table).
#
# Each **row** and **column** has a label (index and column names), which allows for flexible data manipulation, selection, and alignment.
#
# Pandas DataFrame main characteristics include:
#
# * **Two-dimensional** structure (rows and columns)
# * Each column is a **Pandas Series**
# * Columns can hold **different data types**
# * Supports **powerful indexing, slicing, and filtering**
# * Built-in support for **missing data**, **grouping**, **merging**, **pivoting**, and **reshaping**
# * Integrates well with **NumPy**, **Matplotlib**, and other Python libraries
#
# DataFrames are ideal for working with **structured data** such as CSV files, SQL tables, Excel sheets, and JSON. They offer spreadsheet-like functionality with the power of Python programming.
#
# Unlike NumPy arrays, DataFrames are **label-aware** and much more **flexible** in handling real-world data with mixed types and irregular shapes.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # DataFrame Creation & Basic Attributes

# %% [markdown]
# We'll keep our analysis of G7 but more extended version compared to the one we used at Series Countries and looking now at DataFrames. As said, a DataFrame looks a lot like a table
#
# (as the one you can appreciate [here](https://docs.google.com/spreadsheets/d/1IlorV2-Oh9Da1JAZ7weVw86PQrQydSMp-ydVMH135iI/edit?usp=sharing)):
#
# <img width="700" src="https://user-images.githubusercontent.com/872296/38153492-72c032ca-3443-11e8-80f4-9de9060a5127.png" />

# %% [markdown]
# ## Adding each column at a time

# %%
df = pd.DataFrame()  # empty dataframe
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# lets add first column
df["Population"] = [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523]
df
# Out:
#    Population
# 0      35.467
# 1      63.951
# 2      80.940
# 3      60.665
# 4     127.061
# 5      64.511
# 6     318.523

# %%
# second column
df["GDP"] = [1785387, 2833687, 3874437, 2167744, 4602367, 2950039, 17348075]
df
# Out:
#    Population       GDP
# 0      35.467   1785387
# 1      63.951   2833687
# 2      80.940   3874437
# 3      60.665   2167744
# 4     127.061   4602367
# 5      64.511   2950039
# 6     318.523  17348075

# %%
# third column
df["Surface Area"] = [9984670, 640679, 357114, 301336, 377930, 242495, 9525067]
df
# Out:
#    Population       GDP  Surface Area
# 0      35.467   1785387       9984670
# 1      63.951   2833687        640679
# 2      80.940   3874437        357114
# 3      60.665   2167744        301336
# 4     127.061   4602367        377930
# 5      64.511   2950039        242495
# 6     318.523  17348075       9525067

# %%
# 4th
df["HDI"] = [0.913, 0.888, 0.916, 0.873, 0.891, 0.907, 0.915]
df
# Out:
#    Population       GDP  Surface Area    HDI
# 0      35.467   1785387       9984670  0.913
# 1      63.951   2833687        640679  0.888
# 2      80.940   3874437        357114  0.916
# 3      60.665   2167744        301336  0.873
# 4     127.061   4602367        377930  0.891
# 5      64.511   2950039        242495  0.907
# 6     318.523  17348075       9525067  0.915

# %%
# 5th
df["Continent"] = [
    "America",
    "Europe",
    "Europe",
    "Europe",
    "Asia",
    "Europe",
    "America",
]
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %% [markdown]
# ## Column and index
#
# Note that the dataframe we just made has columns and indexes. And we just add columns as attribute while creation. _(The `columns` attribute is optional. I'm using it to keep the same order as in the picture above)_
#
# `DataFrame`s also have indexes. As you can see in the "table" above, pandas has assigned a numeric, auto-incremental index automatically to each "row" in our DataFrame. In our case, we know that each row represents a country, so we'll just reassign the index:

# %% [markdown]
# ### Index

# %%
# initially, by default, we have range index
idx = df.index
print(type(idx))
print(idx)
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>
# RangeIndex(start=0, stop=7, step=1)

# %%
# lets set string index

df.index = [
    "Canada",
    "France",
    "Germany",
    "Italy",
    "Japan",
    "United Kingdom",
    "United States",
]
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
idx = df.index
print(type(idx))
print(idx)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %% [markdown]
# ### Columns
# Notice the type of columns is also `index`

# %%
# remember we assign columns as attribute "columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])"
col = df.columns
print(type(col))
print(col)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %% [markdown]
# ## Shape, Size, Dtype

# %%
df.size
# Out:
# 35

# %%
print("Row count", df.shape[0])
print("Column count", df.shape[1])
# Out:
# Row count 7
# Column count 5

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %% [markdown]
# ## Using dictionary and list (one code call)

# %% [markdown]
# ### Note: Do not worry about how to create dataframe using dictionary.
#
# Consider the code to create df is just given
#
# Creating `DataFrame`s manually can be tedious. 99% of the time you'll be pulling the data from a Database, a csv file or the web. But still, you can create a DataFrame by specifying the columns and values:

# %%
df = pd.DataFrame(
    {
        "Population": [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523],
        "GDP": [1785387, 2833687, 3874437, 2167744, 4602367, 2950039, 17348075],
        "Surface Area": [9984670, 640679, 357114, 301336, 377930, 242495, 9525067],
        "HDI": [0.913, 0.888, 0.916, 0.873, 0.891, 0.907, 0.915],
        "Continent": [
            "America",
            "Europe",
            "Europe",
            "Europe",
            "Asia",
            "Europe",
            "America",
        ],
    },
    columns=["Population", "GDP", "Surface Area", "HDI", "Continent"],
    index=[
        "Canada",
        "France",
        "Germany",
        "Italy",
        "Japan",
        "United Kingdom",
        "United States",
    ],
)

df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %% [markdown]
# ## Highly recommend to save backup

# %%
df0 = df.copy()
df0
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# # DataFrame export and import

# %%
df0.to_csv("my-csv-file1.csv")

# %%
df0.to_csv("my-csv-file2.csv", sep="\t")

# %%
x = pd.read_csv("my-csv-file1.csv")
x
# Out:
#        Unnamed: 0  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
x = pd.read_csv("my-csv-file1.csv", index_col=0)
x
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # Methods for `Data Exploration`
# - just same as what we did for series

# %% [markdown]
# ## describe and info

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %% [markdown]
# ## value counts

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Europe     4
# America    2
# Asia       1
# Name: count, dtype: int64

# %% [markdown]
# type is series!

# %%
type(df["Continent"].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## we can also do plotting

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df["Continent"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Question. Why we didn't try value_counts() and plotting on g7_pop series previously?

# %% [markdown]
# ## Group by

# %%
df.groupby("Continent")

# %%
df.groupby("Continent")["GDP"].mean()
# Out:
# Continent
# America    9566731.00
# Asia       4602367.00
# Europe     2956476.75
# Name: GDP, dtype: float64

# %%
df.groupby("Continent")["GDP"].mean().to_frame()
# Out:
#                   GDP
# Continent
# America    9566731.00
# Asia       4602367.00
# Europe     2956476.75

# %%
df.groupby("Continent")["GDP"].mean().plot(kind="pie")
# Out:
# <Axes: ylabel='GDP'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # Indexing, Selection and Slicing
#
# Individual columns in the DataFrame can be selected with regular indexing. Each column is represented as a `Series`:

# %%
df  # recall
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ## loc and iloc and using braket

# %%
# Germany GDP = 3874437
df.iloc[2, 1]
# Out:
# np.int64(3874437)

# %%
# bottom right corner
df.iloc[-1, -1]
# Out:
# 'America'

# %%
df.iloc[-1].iloc[-1]  # this is possible (chained indexing)
# Out:
# 'America'

# %%
df.loc["Canada"]  # getting a row
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
# df["Canada"]  # error Canada is NOT one of columns

# %%
df["Population"]  # getting a column
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
# df.loc["Population"]

# %% [markdown]
# ## Series slicing
#
# Note that the `index` of the returned Series is the same as the DataFrame one. And its `name` is the name of the column. If you're working on a notebook and want to see a more DataFrame-like format you can use the `to_frame` method:

# %%
sr = df.loc["Canada"]
# note that taking single row or column will result Series NOT dataframe
print(type(df))
print(type(sr))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
sr = df["Population"]
# note that taking single row or column will result Series NOT dataframe
print(type(df))
print(type(sr))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### series to frame

# %%
df["Population"].to_frame()  # use to_frame() to convert Series to DataFrame
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %%
df[["Population"]]
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %% [markdown]
# ## Multiple Indexing
#
# Multiple columns can also be selected similarly to `numpy` and `Series`:

# %%
df  # recall
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df[["Population", "GDP"]]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %% [markdown]
# In this case, the result is another `DataFrame`. Slicing works differently, it acts at "row level", and can be counter intuitive:

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.iloc[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %% [markdown]
# Row level selection works better with `loc` and `iloc` **which are recommended** over regular "direct slicing" (`df[:]`).
#
# `loc` selects rows matching the given index:

# %%
# common error -> this is like getting row of France and column of Italy
# df.loc["France", "Italy"]

# %%
df.loc[["France", "Italy"]]
# Out:
#         Population      GDP  Surface Area    HDI Continent
# France      63.951  2833687        640679  0.888    Europe
# Italy       60.665  2167744        301336  0.873    Europe

# %%
df.loc["France":"Italy"]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe

# %% [markdown]
# As a second "argument", you can pass the column(s) you'd like to select:

# %%
df.loc["France":"Italy", "Population"]
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: Population, dtype: float64

# %%
df.loc["France":"Italy", ["Population", "GDP"]]
# Out:
#          Population      GDP
# France       63.951  2833687
# Germany      80.940  3874437
# Italy        60.665  2167744

# %% [markdown]
# `iloc` works with the (numeric) "position" of the index:

# %%
df  # recall
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.iloc[0]  # df.iloc[0, :]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]  # df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df.iloc[[0, 1, -1]]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Canada             35.467   1785387       9984670  0.913   America
# France             63.951   2833687        640679  0.888    Europe
# United States     318.523  17348075       9525067  0.915   America

# %%
df.iloc[1:3, :-2]
# Out:
#          Population      GDP  Surface Area
# France       63.951  2833687        640679
# Germany      80.940  3874437        357114

# %%
df.iloc[1:3, 3]
# Out:
# France     0.888
# Germany    0.916
# Name: HDI, dtype: float64

# %%
df.iloc[1:3, [0, 3]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.916

# %%
df.iloc[1:3, 1:3]
# Out:
#              GDP  Surface Area
# France   2833687        640679
# Germany  3874437        357114

# %% [markdown]
# > **RECOMMENDED: Always use `loc` and `iloc` to reduce ambiguity, specially with `DataFrame`s with numeric indexes.**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Conditional selection (boolean arrays)
#
# We saw conditional selection applied to `Series` and it'll work in the same way for `DataFrame`s. After all, a `DataFrame` is a collection of `Series`:

# %%
df
# Out:
# /Users/I751244/Desktop/soop/datascience/ds101/.venv/lib/python3.12/site-packages/IPython/core/displayhook.py:292: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df["Population"] > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df.loc[df["Population"] > 70]  # standard
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
df[df["Population"] > 70]  # same result
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %% [markdown]
# The boolean matching is done at Index level, so you can filter by any row, as long as it contains the right indexes. Column selection still works as expected:

# %%
df.loc[df["Population"] > 70, "Population"]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: Population, dtype: float64

# %%
# df[df["Population"] > 70, "Population"]  # error

# %%
df.loc[df["Population"] > 70, ["Population", "GDP"]]
# Out:
#                Population       GDP
# Germany            80.940   3874437
# Japan             127.061   4602367
# United States     318.523  17348075

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # Modifying DataFrame

# %% [markdown]
# ---
# ## Dropping stuff
# - We are going to learn about data cleaning more detail in future. Here is just short introduction
#
# Opposed to the concept of selection, we have "dropping". Instead of pointing out which values you'd like to _select_ you could point which ones you'd like to `drop`:

# %% [markdown]
# I am going to create `df0` for backup because I do not want to modify the original version

# %%
df0 = df.copy()  # DO NOT DELETE

# %%
df = df0.copy()
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop("Japan")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df  # reprinting, and it still has Japan. You must know why
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df = df.drop("Japan")  # Now you won't see Japan
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ### Avoiding key error when drop

# %%
# df.drop("Japan") # key error because you are dropping you already dropped

# %%
df.drop("Japan", errors="ignore")  # lets ignore errors
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ### Dropping many rows

# %%
df.drop(["Canada", "United States"])
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# France              63.951  2833687        640679  0.888    Europe
# Germany             80.940  3874437        357114  0.916    Europe
# Italy               60.665  2167744        301336  0.873    Europe
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df.drop(df[df["Continent"] == "America"].index)
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# France              63.951  2833687        640679  0.888    Europe
# Germany             80.940  3874437        357114  0.916    Europe
# Italy               60.665  2167744        301336  0.873    Europe
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df.drop(["Canada", "Japan", "South Korea", "North Korea"], errors="ignore")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ### Dropping with axis specified

# %%
df.drop(columns=["Population", "HDI"])  # if you want to drop columns
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(["Italy", "France"], axis=0)  # axis=0 is actually no need
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# Germany             80.940   3874437        357114  0.916    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(["Population", "HDI"], axis=1)
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(["Population", "HDI"], axis=1)
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(["Population", "HDI"], axis="columns")
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(["France", "Germany"], axis="rows")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ## Inplace=True Attribute
# All these `drop` methods return a new `DataFrame`. If you'd like to modify it "in place", you can use the `inplace` attribute

# %%
df = df0.copy()
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(["France", "Germany"], axis="rows", inplace=True)
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ---
# ## Vectorized Operations

# %%
df = df0.copy()
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
# df[["Surface Area", "Population", "Continent"]] / 100 # error. why?!

# %%
df[["Surface Area", "Population", "GDP"]] / 100
# Out:
#                 Surface Area  Population        GDP
# Canada              99846.70     0.35467   17853.87
# France               6406.79     0.63951   28336.87
# Germany              3571.14     0.80940   38744.37
# Italy                3013.36     0.60665   21677.44
# Japan                3779.30     1.27061   46023.67
# United Kingdom       2424.95     0.64511   29500.39
# United States       95250.67     3.18523  173480.75

# %%
df[["Surface Area", "Population", "GDP"]].mean()
# Out:
# Surface Area    3.061327e+06
# Population      1.073026e+02
# GDP             5.080248e+06
# dtype: float64

# %% [markdown]
# ---
# ## Sort

# %%
df = df0.copy()
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.sort_index(ascending=False)
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# United States      318.523  17348075       9525067  0.915   America
# United Kingdom      64.511   2950039        242495  0.907    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# Italy               60.665   2167744        301336  0.873    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# France              63.951   2833687        640679  0.888    Europe
# Canada              35.467   1785387       9984670  0.913   America

# %%
df  # wasn't overwritten
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.sort_index(ascending=False, inplace=True)
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# United States      318.523  17348075       9525067  0.915   America
# United Kingdom      64.511   2950039        242495  0.907    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# Italy               60.665   2167744        301336  0.873    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# France              63.951   2833687        640679  0.888    Europe
# Canada              35.467   1785387       9984670  0.913   America

# %%
df.sort_values("HDI")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Italy               60.665   2167744        301336  0.873    Europe
# France              63.951   2833687        640679  0.888    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# Canada              35.467   1785387       9984670  0.913   America
# United States      318.523  17348075       9525067  0.915   America
# Germany             80.940   3874437        357114  0.916    Europe

# %%
df.sort_values("Population")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# Italy               60.665   2167744        301336  0.873    Europe
# France              63.951   2833687        640679  0.888    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United States      318.523  17348075       9525067  0.915   America

# %%
df.sort_values("Continent")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# United States      318.523  17348075       9525067  0.915   America
# Canada              35.467   1785387       9984670  0.913   America
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# France              63.951   2833687        640679  0.888    Europe

# %%
df.sort_values(["Continent", "GDP"])  # more than one
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# United States      318.523  17348075       9525067  0.915   America
# Japan              127.061   4602367        377930  0.891      Asia
# Italy               60.665   2167744        301336  0.873    Europe
# France              63.951   2833687        640679  0.888    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# Germany             80.940   3874437        357114  0.916    Europe

# %% [markdown]
# ## Resetting index

# %%
df = df0.copy()
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.reset_index(inplace=True)
df
# Out:
#             index  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df.reset_index(inplace=True)  # when you do this again
df
# Out:
#    level_0           index  Population       GDP  Surface Area    HDI  \
# 0        0          Canada      35.467   1785387       9984670  0.913
# 1        1          France      63.951   2833687        640679  0.888
# 2        2         Germany      80.940   3874437        357114  0.916
# 3        3           Italy      60.665   2167744        301336  0.873
# 4        4           Japan     127.061   4602367        377930  0.891
# 5        5  United Kingdom      64.511   2950039        242495  0.907
# 6        6   United States     318.523  17348075       9525067  0.915
#
#   Continent
# 0   America
# 1    Europe
# 2    Europe
# 3    Europe
# 4      Asia
# 5    Europe
# 6   America

# %%
# df.reset_index(inplace=True)  # when you do this again two more. error!

# `ValueError: cannot insert level_0, already exists``

# %%
df.set_index("HDI")
# Out:
#        level_0           index  Population       GDP  Surface Area Continent
# HDI
# 0.913        0          Canada      35.467   1785387       9984670   America
# 0.888        1          France      63.951   2833687        640679    Europe
# 0.916        2         Germany      80.940   3874437        357114    Europe
# 0.873        3           Italy      60.665   2167744        301336    Europe
# 0.891        4           Japan     127.061   4602367        377930      Asia
# 0.907        5  United Kingdom      64.511   2950039        242495    Europe
# 0.915        6   United States     318.523  17348075       9525067   America

# %% [markdown]
# ## Renaming

# %%
df = df0.copy()
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.columns = ["Pop", "GDP", "SurfArea", "HDI", "Cont"]
df
# Out:
#                     Pop       GDP  SurfArea    HDI     Cont
# Canada           35.467   1785387   9984670  0.913  America
# France           63.951   2833687    640679  0.888   Europe
# Germany          80.940   3874437    357114  0.916   Europe
# Italy            60.665   2167744    301336  0.873   Europe
# Japan           127.061   4602367    377930  0.891     Asia
# United Kingdom   64.511   2950039    242495  0.907   Europe
# United States   318.523  17348075   9525067  0.915  America

# %%
# no key error for APC or Argentina
df = df.rename(
    columns={
        "HDI": "Human Development Index",
        "APC": "Anual Popcorn Consumption",
    },
    index={"United States": "USA", "United Kingdom": "UK", "Argentina": "AR"},
)
df
# Out:
#              Pop       GDP  SurfArea  Human Development Index     Cont
# Canada    35.467   1785387   9984670                    0.913  America
# France    63.951   2833687    640679                    0.888   Europe
# Germany   80.940   3874437    357114                    0.916   Europe
# Italy     60.665   2167744    301336                    0.873   Europe
# Japan    127.061   4602367    377930                    0.891     Asia
# UK        64.511   2950039    242495                    0.907   Europe
# USA      318.523  17348075   9525067                    0.915  America

# %%
df.rename(index=str.upper)
# Out:
#              Pop       GDP  SurfArea  Human Development Index     Cont
# CANADA    35.467   1785387   9984670                    0.913  America
# FRANCE    63.951   2833687    640679                    0.888   Europe
# GERMANY   80.940   3874437    357114                    0.916   Europe
# ITALY     60.665   2167744    301336                    0.873   Europe
# JAPAN    127.061   4602367    377930                    0.891     Asia
# UK        64.511   2950039    242495                    0.907   Europe
# USA      318.523  17348075   9525067                    0.915  America

# %%
df.rename(index=lambda x: "*" + x + "*")
# Out:
#                Pop       GDP  SurfArea  Human Development Index     Cont
# *Canada*    35.467   1785387   9984670                    0.913  America
# *France*    63.951   2833687    640679                    0.888   Europe
# *Germany*   80.940   3874437    357114                    0.916   Europe
# *Italy*     60.665   2167744    301336                    0.873   Europe
# *Japan*    127.061   4602367    377930                    0.891     Asia
# *UK*        64.511   2950039    242495                    0.907   Europe
# *USA*      318.523  17348075   9525067                    0.915  America

# %%
df.rename(index=lambda x: x[:3] + "***")
# Out:
#             Pop       GDP  SurfArea  Human Development Index     Cont
# Can***   35.467   1785387   9984670                    0.913  America
# Fra***   63.951   2833687    640679                    0.888   Europe
# Ger***   80.940   3874437    357114                    0.916   Europe
# Ita***   60.665   2167744    301336                    0.873   Europe
# Jap***  127.061   4602367    377930                    0.891     Asia
# UK***    64.511   2950039    242495                    0.907   Europe
# USA***  318.523  17348075   9525067                    0.915  America

# %% [markdown]
# ## Adding columns

# %%
df = df0.copy()
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ### Adding by braket

# %%
df["Lang"] = "undecided"
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent       Lang
# Canada              35.467   1785387       9984670  0.913   America  undecided
# France              63.951   2833687        640679  0.888    Europe  undecided
# Germany             80.940   3874437        357114  0.916    Europe  undecided
# Italy               60.665   2167744        301336  0.873    Europe  undecided
# Japan              127.061   4602367        377930  0.891      Asia  undecided
# United Kingdom      64.511   2950039        242495  0.907    Europe  undecided
# United States      318.523  17348075       9525067  0.915   America  undecided

# %% [markdown]
# ### adding column by `.assign()`

# %%
df.assign(President="Trump")
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                      Lang President
# Canada          undecided     Trump
# France          undecided     Trump
# Germany         undecided     Trump
# Italy           undecided     Trump
# Japan           undecided     Trump
# United Kingdom  undecided     Trump
# United States   undecided     Trump

# %%
df  # no change
# Out:
#                 Population       GDP  Surface Area    HDI Continent       Lang
# Canada              35.467   1785387       9984670  0.913   America  undecided
# France              63.951   2833687        640679  0.888    Europe  undecided
# Germany             80.940   3874437        357114  0.916    Europe  undecided
# Italy               60.665   2167744        301336  0.873    Europe  undecided
# Japan              127.061   4602367        377930  0.891      Asia  undecided
# United Kingdom      64.511   2950039        242495  0.907    Europe  undecided
# United States      318.523  17348075       9525067  0.915   America  undecided

# %% [markdown]
# ### adding column using `.loc` or `.iloc`

# %%
df.loc[:, "President"] = "Trump"
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                      Lang President
# Canada          undecided     Trump
# France          undecided     Trump
# Germany         undecided     Trump
# Italy           undecided     Trump
# Japan           undecided     Trump
# United Kingdom  undecided     Trump
# United States   undecided     Trump

# %% [markdown]
# ### adding column by `.insert()`

# %%
df.insert(2, "GDP per Capita", (df["GDP"] / df["Population"]).round(2))  # at 3rd column
df
# Out:
#                 Population       GDP  GDP per Capita  Surface Area    HDI  \
# Canada              35.467   1785387        50339.39       9984670  0.913
# France              63.951   2833687        44310.28        640679  0.888
# Germany             80.940   3874437        47868.01        357114  0.916
# Italy               60.665   2167744        35733.03        301336  0.873
# Japan              127.061   4602367        36221.71        377930  0.891
# United Kingdom      64.511   2950039        45729.24        242495  0.907
# United States      318.523  17348075        54464.12       9525067  0.915
#
#                Continent       Lang President
# Canada           America  undecided     Trump
# France            Europe  undecided     Trump
# Germany           Europe  undecided     Trump
# Italy             Europe  undecided     Trump
# Japan               Asia  undecided     Trump
# United Kingdom    Europe  undecided     Trump
# United States    America  undecided     Trump

# %% [markdown]
# | Method                         | Description                                     |
# | ------------------------------ | ----------------------------------------------- |
# | `df['col'] = ...`              | The most common and direct way to add a column. |
# | `df.assign(col=...)`           | Functional style; returns a new DataFrame.      |
# | `df.insert(pos, 'col', value)` | Inserts a column at a specific position.        |
# | `df.loc[:, 'col'] = ...`       | Assigns values using label-based indexing.      |
# | `df['col'] = df.apply(...)`    | Good for row-wise operations or custom logic.   |

# %% [markdown]
# ### adding column using `.concat()`

# %%
shuffled_index = df0.sample(7).index
shuffled_index
# Out:
# Index(['France', 'Germany', 'Canada', 'Italy', 'United States',
#        'United Kingdom', 'Japan'],
#       dtype='object')

# %%
sr = pd.Series(index=shuffled_index, data=range(11, 18))
sr
# Out:
# France            11
# Germany           12
# Canada            13
# Italy             14
# United States     15
# United Kingdom    16
# Japan             17
# dtype: int64

# %%
pd.concat(
    [df, sr], axis=1
)  # it is not just simple concating. It will be joined by index!
# Out:
#                 Population       GDP  GDP per Capita  Surface Area    HDI  \
# Canada              35.467   1785387        50339.39       9984670  0.913
# France              63.951   2833687        44310.28        640679  0.888
# Germany             80.940   3874437        47868.01        357114  0.916
# Italy               60.665   2167744        35733.03        301336  0.873
# Japan              127.061   4602367        36221.71        377930  0.891
# United Kingdom      64.511   2950039        45729.24        242495  0.907
# United States      318.523  17348075        54464.12       9525067  0.915
#
#                Continent       Lang President  Population
# Canada           America  undecided     Trump      35.467
# France            Europe  undecided     Trump      63.951
# Germany           Europe  undecided     Trump      80.940
# Italy             Europe  undecided     Trump      60.665
# Japan               Asia  undecided     Trump     127.061
# United Kingdom    Europe  undecided     Trump      64.511
# United States    America  undecided     Trump     318.523

# %%
df  # won't change
# Out:
#                 Population       GDP  GDP per Capita  Surface Area    HDI  \
# Canada              35.467   1785387        50339.39       9984670  0.913
# France              63.951   2833687        44310.28        640679  0.888
# Germany             80.940   3874437        47868.01        357114  0.916
# Italy               60.665   2167744        35733.03        301336  0.873
# Japan              127.061   4602367        36221.71        377930  0.891
# United Kingdom      64.511   2950039        45729.24        242495  0.907
# United States      318.523  17348075        54464.12       9525067  0.915
#
#                Continent       Lang President
# Canada           America  undecided     Trump
# France            Europe  undecided     Trump
# Germany           Europe  undecided     Trump
# Italy             Europe  undecided     Trump
# Japan               Asia  undecided     Trump
# United Kingdom    Europe  undecided     Trump
# United States    America  undecided     Trump

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # More Activity (Crisis)

# %% [markdown]
# **Operations with Series** work at a column level, broadcasting down the rows (which can be counter intuitive).

# %%
crisis = pd.Series([-1_000_000, -0.3], index=["GDP", "HDI"])
crisis

# %%
df[["GDP", "HDI"]]

# %%
df[["GDP", "HDI"]] + crisis

# %% [markdown]
# It's simple and intuitive, You can add columns, or replace values for columns without issues:

# %%
# this is just given
langs = pd.Series(
    ["French", "German", "Italian"],
    index=["France", "Germany", "Italy"],
    name="Language",
)

langs

# %%
df["Language"] = langs
df

# %% [markdown]
# ---
#
# ### Replacing values per column

# %%
df["Language"] = "English"  # broadcasting
df

# %%
df["President"] = "Trump"
df

# %%
df["Language"] = langs
df

# %%
# drop trump
df = df.drop("President", axis=1)
df

# %%
# drop trump again with error
df = df.drop("President", axis=1)
df

# %%
df = df.drop("President", axis=1, errors="others")
df

# %%
df0 = df.copy()
df.drop(columns="GDP", inplace=True)  # save without equal sign

# %%
df = df0  # rollback
df

# %%
newdf = pd.Series({"Population": 3, "GDP": 5})
pd.concat([df, newdf])

# %% [markdown]
# Append returns a new `DataFrame`:

# %%
df

# %% [markdown]
# You can directly set the new index and values to the `DataFrame`:

# %%
df.loc["China"] = pd.Series({"Population": 1_400_000_000, "Continent": "Asia"})

# %%
df

# %% [markdown]
# We can use `drop` to just remove a row by index:

# %%
df.drop("China", inplace=True)

# %%
df

# %%
df.groupby("Continent").mean()

# %%
df.groupby("HDI").mean()  # cannot group by based on number value

# %% [markdown]
# # AND MANY MORE!!
# - join
# - melt
# - apply
# - applymap
