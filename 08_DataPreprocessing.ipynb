# %% [markdown]
# <img src="https://user-images.githubusercontent.com/7065401/39117173-a433bf6a-46e6-11e8-8a40-b4d4d6422493.jpg"
#     style="width:300px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # 🧹  Data Preprocessing
#
#
# In any data-driven project, one of the most time-consuming and crucial steps is data preprocessing—the process of transforming raw data into a clean and usable format. Within this stage, data cleansing (or data cleaning) plays a central role.
#
# ### What is Data Preprocessing?
# Data preprocessing refers to a series of steps taken to prepare raw data for analysis or machine learning. This may include:
# - Removing duplicates or irrelevant observations
# - Handling missing values
# - Converting data types
# - Normalizing or scaling features
# - Encoding categorical variables
#
# ### What is Data Cleansing?
# Data cleansing is a subset of data preprocessing that focuses on identifying and correcting (or removing) errors and inconsistencies in the data. These errors may come from various sources such as manual data entry, sensor malfunctions, or inconsistent data formats.
#
# Examples include:
# - Fixing typos or inconsistent text formats ("Male" vs "male")
# - Handling null or NaN values
# - Removing outliers or incorrect values
#
# ### Why is This Important?
# > 💡 “Garbage in, garbage out.” – A common saying in data science.
# If the data going into your analysis or model is inaccurate or inconsistent, the results will likely be unreliable. Clean, well-prepared data leads to:
# - More accurate analyses and visualizations
# - Better-performing machine learning models
# - More trustworthy insights for decision-making
#
# In fact, in many real-world industry projects, data preprocessing can take up to 70–80% of the total time. While model building may seem more exciting, it’s the quality of the data that often determines the success of a project.

# %% [markdown]
# ![separator2](https://i.imgur.com/4gX5WFr.png)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Filling and Dropping NaN

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", None],
    "Age": [25, np.nan, 30, np.nan, 22, 28],
    "Score": [85.0, 90.5, np.nan, 76.0, np.nan, np.nan],
    "Gender": ["F", "M", "M", None, "F", "M"],
}

df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Score Gender
# 0    Alice  25.0   85.0      F
# 1      Bob   NaN   90.5      M
# 2  Charlie  30.0    NaN      M
# 3    David   NaN   76.0   None
# 4      Eve  22.0    NaN      F
# 5     None  28.0    NaN      M

# %% [markdown]
# ## Dropping NaN values

# %%
df.dropna()
# Out:
#     Name   Age  Score Gender
# 0  Alice  25.0   85.0      F

# %%
df.dropna(subset=["Score"])
# Out:
#     Name   Age  Score Gender
# 0  Alice  25.0   85.0      F
# 1    Bob   NaN   90.5      M
# 3  David   NaN   76.0   None

# %%
df.dropna(subset=["Age"])
# Out:
#       Name   Age  Score Gender
# 0    Alice  25.0   85.0      F
# 2  Charlie  30.0    NaN      M
# 4      Eve  22.0    NaN      F
# 5     None  28.0    NaN      M

# %%
df.dropna(subset=["Score", "Age"])
# Out:
#     Name   Age  Score Gender
# 0  Alice  25.0   85.0      F

# %%
print(df["Score"])
print(df["Score"].fillna(0))
# Out:
# 0    85.0
# 1    90.5
# 2     NaN
# 3    76.0
# 4     NaN
# 5     NaN
# Name: Score, dtype: float64
# 0    85.0
# 1    90.5
# 2     0.0
# 3    76.0
# 4     0.0
# 5     0.0
# Name: Score, dtype: float64

# %%
print(df["Age"])
print(df["Age"].fillna(df["Age"].mean()))
# Out:
# 0    25.0
# 1     NaN
# 2    30.0
# 3     NaN
# 4    22.0
# 5    28.0
# Name: Age, dtype: float64
# 0    25.00
# 1    26.25
# 2    30.00
# 3    26.25
# 4    22.00
# 5    28.00
# Name: Age, dtype: float64

# %% [markdown]
# # Finding Abnormal Values
#
# After dealing with many datasets I can tell you that "missing data" is not such a big deal. The best thing that can happen is to clearly see values like `np.nan`. The only thing you need to do is just use methods like `isnull` and `fillna`/`dropna` and pandas will take care of the rest.
#
# But sometimes, you can have invalid values that are not just "missing data" (`None`, or `nan`). For example:

# %%
df = pd.DataFrame(
    {
        "Gender": ["M", "F", "F", "D", "?", "F", "?", "M", "M"],
        "Age": [29, 30, 24, 290, 25, 19, 40, 11, 288],
    }
)
df
# Out:
#   Gender  Age
# 0      M   29
# 1      F   30
# 2      F   24
# 3      D  290
# 4      ?   25
# 5      F   19
# 6      ?   40
# 7      M   11
# 8      M  288

# %% [markdown]
# This dataframe doesn't have any "missing value", but clearly has invalid data. `290` doesn't seem like a valid age, and `D` and `?` don't correspond with any known sex category. How can you clean these not-missing, but clearly invalid values then?`
#
# The first step to clean invalid values is to **notice** them, then **identify** them and finally handle them appropriately (remove them, replace them, etc). Usually, for a "categorical" type of field (like Sex, which only takes values of a discrete set `('M', 'F')`), we start by analyzing the variety of values present. For that, we use the `unique()` method:

# %% [markdown]
# ### use `.unique()` to identify

# %%
df["Gender"].unique()
# Out:
# array(['M', 'F', 'D', '?'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    3
# F    3
# ?    2
# D    1
# Name: count, dtype: int64

# %% [markdown]
# ### replace it using `.replace()`

# %% [markdown]
# Clearly if you see values like `'D'` or `'?'`, it'll immediately raise your attention. Now, what to do with them? Let's say you picked up the phone, called the survey company and they told you that `'D'` was a typo and it should actually be `F`.

# %%
# You can use the `replace` function to replace these values:
df["Gender"].replace("D", "F")
# Out:
# 0    M
# 1    F
# 2    F
# 3    F
# 4    ?
# 5    F
# 6    ?
# 7    M
# 8    M
# Name: Gender, dtype: object

# %%
# It can accept a dictionary of values to replace.
# For example, they also told you that there might be a few `'?'s`, that should actually be `'M's`:
df["Gender"].replace({"D": "F", "?": "M"})
# Out:
# 0    M
# 1    F
# 2    F
# 3    F
# 4    M
# 5    F
# 6    M
# 7    M
# 8    M
# Name: Gender, dtype: object

# %%
# If you have many columns to replace, you could apply it at "DataFrame level":
df.replace({"Gender": {"D": "F", "?": "M"}, "Age": {290: 29}})
# Out:
#   Gender  Age
# 0      M   29
# 1      F   30
# 2      F   24
# 3      F   29
# 4      M   25
# 5      F   19
# 6      M   40
# 7      M   11
# 8      M  288

# %%
df.replace({"Gender": {"D": "F", "?": "M"}, "Age": {290: 29}}, inplace=True)
df
# Out:
#   Gender  Age
# 0      M   29
# 1      F   30
# 2      F   24
# 3      F   29
# 4      M   25
# 5      F   19
# 6      M   40
# 7      M   11
# 8      M  288

# %% [markdown]
# In the previous example, I explicitly replaced 290 with 29 (assuming it was just an extra 0 entered at data-entry phase). But what if you'd like to remove all the extra 0s from the ages columns? (example, `150 > 15`, `490 > 49`).
#
# The first step would be to just set the limit of the "not possible" age. Is it 100? 120? Let's say that anything above 100 isn't credible for **our** dataset. Also, we do not want underage. We can then combine boolean selection with the operation:

# %%
df[(df["Age"] > 100) | (df["Age"] < 18)]
# Out:
#   Gender  Age
# 7      M   11
# 8      M  288

# %% [markdown]
# And we can now just divide by 10 who is older than 100, and drop who is underage

# %%
df = df[df["Age"] >= 18]
df.loc[df["Age"] > 100, "Age"] = df.loc[df["Age"] > 100, "Age"] / 10
df
# Out:
# /var/folders/0s/p6r6pj_15m5cg5q_gj8_xdjm0000gn/T/ipykernel_89562/2324351843.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[28.8]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Age"] > 100, "Age"] = df.loc[df["Age"] > 100, "Age"] / 10
#   Gender   Age
# 0      M  29.0
# 1      F  30.0
# 2      F  24.0
# 3      F  29.0
# 4      M  25.0
# 5      F  19.0
# 6      M  40.0
# 8      M  28.8

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# # Duplicates
#
# Checking duplicate values is extremely simple. It'll behave differently between Series and DataFrames. Let's start with Series. As an example, let's say we're throwing a fancy party and we're inviting Ambassadors from Europe. But can only invite one ambassador per country. This is our original list, and as you can see, both the UK and Germany have duplicated ambassadors:

# %% [markdown]
# ## Duplicates in Series

# %%
ambassadors = pd.Series(
    [
        "France",
        "United Kingdom",
        "United Kingdom",
        "Italy",
        "Germany",
        "Germany",
        "Germany",
    ],
    index=[
        "Gérard Araud",
        "Kim Darroch",
        "Peter Westmacott",
        "Armando Varricchio",
        "Peter Wittig",
        "Peter Ammon",
        "Klaus Scharioth ",
    ],
)
ambassadors
# Out:
# Gérard Araud                  France
# Kim Darroch           United Kingdom
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# Peter Ammon                  Germany
# Klaus Scharioth              Germany
# dtype: object

# %% [markdown]
# The two most important methods to deal with duplicates are `duplicated` (that will tell you which values are duplicates) and `drop_duplicates` (which will just get rid of duplicates):

# %%
ambassadors.duplicated()
# Out:
# Gérard Araud          False
# Kim Darroch           False
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig          False
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %% [markdown]
# In this case `duplicated` didn't consider `'Kim Darroch'`, the first instance of the United Kingdom or `'Peter Wittig'` as duplicates. That's because, by default, it'll consider the first occurrence of the value as not-duplicate. You can change this behavior with the `keep` parameter:

# %%
ambassadors.duplicated(keep="last")
# Out:
# Gérard Araud          False
# Kim Darroch            True
# Peter Westmacott      False
# Armando Varricchio    False
# Peter Wittig           True
# Peter Ammon            True
# Klaus Scharioth       False
# dtype: bool

# %% [markdown]
# In this case, the result is "flipped", `'Kim Darroch'` and `'Peter Wittig'` (the first ambassadors of their countries) are considered duplicates, but `'Peter Westmacott'` and `'Klaus Scharioth'` are not duplicates. You can also choose to mark all of them as duplicates with `keep=False`:

# %% [markdown]
# A similar method is `drop_duplicates`, which just excludes the duplicated values and also accepts the `keep` parameter:

# %%
ambassadors.drop_duplicates()
# Out:
# Gérard Araud                  France
# Kim Darroch           United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep="last")
# Out:
# Gérard Araud                  France
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Klaus Scharioth              Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep=False)
# Out:
# Gérard Araud          France
# Armando Varricchio     Italy
# dtype: object

# %% [markdown]
# ## Duplicates in DataFrames
#
# Conceptually speaking, duplicates in a DataFrame happen at "row" level. Two rows with exactly the same values are considered to be duplicates:

# %%
players = pd.DataFrame(
    {
        "Name": [
            "Kobe Bryant",
            "LeBron James",
            "Kobe Bryant",
            "Carmelo Anthony",
            "Kobe Bryant",
        ],
        "Pos": ["SG", "SF", "SG", "SF", "SF"],
    }
)
players
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 2      Kobe Bryant  SG
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.sort_values("Name", ascending=False)
# Out:
#               Name Pos
# 1     LeBron James  SF
# 0      Kobe Bryant  SG
# 2      Kobe Bryant  SG
# 4      Kobe Bryant  SF
# 3  Carmelo Anthony  SF

# %% [markdown]
# In the previous DataFrame, we clearly see that Kobe is duplicated; but he appears with two different positions. What does `duplicated` say?

# %%
players.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# Again, conceptually, "duplicated" means "all the column values should be duplicates". We can customize this with the `subset` parameter:

# %%
players.duplicated(subset=["Name"])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# And the same rules of `keep` still apply:

# %%
players.duplicated(subset=["Name"], keep="last")
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# `drop_duplicates` takes the same parameters:

# %%
players
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 2      Kobe Bryant  SG
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.drop_duplicates()
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.drop_duplicates(subset=["Name"])
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF

# %%
players.drop_duplicates(subset=["Name"], keep="last")
# Out:
#               Name Pos
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# # Text Handling
#
# Cleaning text values can be incredibly hard. Invalid text values involves, 99% of the time, mistyping, which is completely unpredictable and doesn't follow any pattern. Thankfully, it's not so common these days, where data-entry tasks have been replaced by machines. Still, let's explore the most common cases:
#
# ### Splitting Columns
#
# The result of a survey is loaded and this is what you get:

# %%
df = pd.DataFrame(
    {
        "Data": [
            "1987_M._US _1",
            "1990?_M_UK_1",
            "1992_F_US_2",
            "1970?_M_   IT_1",
            "1985_F_I  T_2",
        ]
    }
)
df
# Out:
#               Data
# 0    1987_M._US _1
# 1     1990?_M_UK_1
# 2      1992_F_US_2
# 3  1970?_M_   IT_1
# 4    1985_F_I  T_2

# %% [markdown]
# You know that the single columns represent the values "year, Gender, Country and number of children", but it's all been grouped in the same column and separated by an underscore. Pandas has a convenient method named `split` that we can use in these situations:

# %%
df["Data"].str.split("_")
# Out:
# 0      [1987, M., US , 1]
# 1       [1990?, M, UK, 1]
# 2        [1992, F, US, 2]
# 3    [1970?, M,    IT, 1]
# 4      [1985, F, I  T, 2]
# Name: Data, dtype: object

# %%
df["Data"].str.split("_", expand=True)
# Out:
#        0   1      2  3
# 0   1987  M.    US   1
# 1  1990?   M     UK  1
# 2   1992   F     US  2
# 3  1970?   M     IT  1
# 4   1985   F   I  T  2

# %%
df = df["Data"].str.split("_", expand=True)
df.columns = ["Year", "Gender", "Country", "Numb_Children"]
df
# Out:
#     Year Gender Country Numb_Children
# 0   1987     M.     US              1
# 1  1990?      M      UK             1
# 2   1992      F      US             2
# 3  1970?      M      IT             1
# 4   1985      F    I  T             2

# %% [markdown]
# but seems like the data still looks ugly. </br>
# How do we know?

# %%
print(df["Year"].unique())
print(df["Gender"].unique())
print(df["Country"].unique())
print(df["Numb_Children"].unique())
# Out:
# ['1987' '1990?' '1992' '1970?' '1985']
# ['M.' 'M' 'F']
# ['US ' 'UK' 'US' '   IT' 'I  T']
# ['1' '2']

# %% [markdown]
# ### strip the spaces
# You can also check which columns contain a given value with the `contains` method </br>
# Removing blank spaces (like in `'US '` or `'I  T'` can be achieved with `strip` (`lstrip` and `rstrip` also exist) or just `replace`:

# %%
df["Country"].str.contains(" ")
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Country, dtype: bool

# %%
df["Country"].str.strip()
# Out:
# 0      US
# 1      UK
# 2      US
# 3      IT
# 4    I  T
# Name: Country, dtype: object

# %%
df["Country"].str.replace(" ", "")
# Out:
# 0    US
# 1    UK
# 2    US
# 3    IT
# 4    IT
# Name: Country, dtype: object

# %%
df["Country"] = df["Country"].str.replace(" ", "")
print(df["Country"].unique())
df
# Out:
# ['US' 'UK' 'IT']
#     Year Gender Country Numb_Children
# 0   1987     M.      US             1
# 1  1990?      M      UK             1
# 2   1992      F      US             2
# 3  1970?      M      IT             1
# 4   1985      F      IT             2

# %% [markdown]
# ### `.contains` beware regular expression

# %% [markdown]
# You can also check which columns contain a given value with the `contains` method:
# - And here you need to use `\\?` not `?`
# - Same way, you need to use `\\.` not `.`
#
# [`contains`](http://pandas.pydata.org/pandas-docs/version/0.22.0/generated/pandas.Series.str.contains.html) takes a regex/pattern as first value, so we need to escape the `?` symbol or `.` as it has a special meaning for these patterns.

# %%
# df["Year"].str.contains("?")  # error!! you need to use \\?
df["Year"].str.contains("\\?")
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Year, dtype: bool

# %%
# print(df["Gender"].str.contains(".")) # no error. but you will get all True
print(df["Gender"].str.contains("\\."))
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Gender, dtype: bool

# %%
df["Year"] = df["Year"].str.replace("?", "")
df["Gender"] = df["Gender"].str.replace(".", "")
df
# Out:
#    Year Gender Country Numb_Children
# 0  1987      M      US             1
# 1  1990      M      UK             1
# 2  1992      F      US             2
# 3  1970      M      IT             1
# 4  1985      F      IT             2

# %%
# print(df["Numb_Children"].mean(), df["Numb_Children"].std().round(2))  # error

# %%
df["Numb_Children"] = df["Numb_Children"].astype(int)
print(df["Numb_Children"].mean(), df["Numb_Children"].std().round(2))
# Out:
# 1.4 0.55
