# %% [markdown]
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Print the pandas version and the configuration
print(np.__version__)
print(pd.__version__)
# Out:
# 2.3.1
# 2.3.0

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ---
# Create an empty pandas DataFrame

# %%
# your code goes here
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ---
# Create a pandas DataFrame with None data None index None columns

# %%
# your code goes here
df = pd.DataFrame(data=[], index=[])
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hero_example
#
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %%
# given data: col_names

col_names = [
    "name",
    "gender",
    "first_appearance",
    "superpower",
    "team",
    "origin",
    "popularity_score",
    "status",
]
print(*col_names)
# Out:
# name gender first_appearance superpower team origin popularity_score status

# %%
# given data: hero:data
hero_data = [
    [
        "Spider-Man",
        "male",
        1962,
        "Wall-crawling, super strength",
        "Avengers",
        "New York",
        9.8,
        "active",
    ],
    [
        "Captain America",
        "male",
        1941,
        "Super soldier strength",
        "Avengers",
        "World War II",
        9.6,
        "active",
    ],
    [
        "Wolverine",
        "male",
        1974,
        "Regeneration, claws",
        "X-Men",
        "Canada",
        9.5,
        "active",
    ],
    [
        "Iron Man",
        "male",
        1963,
        "Genius-level intellect, powered armor",
        "Avengers",
        "New York",
        9.7,
        "deceased",
    ],
    [
        "Thor",
        "male",
        1963,
        "Godly strength, Mjölnir",
        "Avengers",
        "Asgard",
        9.8,
        "active",
    ],
    [
        "Thing",
        "male",
        1961,
        "Rocky skin, super strength",
        "Fantastic Four",
        "New York",
        8.5,
        "active",
    ],
    [
        "Mister Fantastic",
        "male",
        1961,
        "Elastic body",
        "Fantastic Four",
        "New York",
        8.8,
        "active",
    ],
    [
        "Hulk",
        "male",
        1962,
        "Super strength, rage-induced transformation",
        "Avengers",
        "New York",
        9.2,
        "active",
    ],
    [
        "Beast",
        "male",
        1963,
        "Super strength, agility",
        "X-Men",
        "Illinois",
        8.3,
        "active",
    ],
    [
        "Invisible Woman",
        "female",
        1961,
        "Invisibility, force fields",
        "Fantastic Four",
        "New York",
        8.9,
        "active",
    ],
    ["Storm", "female", 1975, "Weather manipulation", "X-Men", "Kenya", 9.1, "active"],
    ["Namor", "male", 1939, "Aquatic abilities", "X-Men", "Atlantis", 7.9, "active"],
    ["Hawkeye", "male", 1964, "Expert archer", "Avengers", "Iowa", 7.8, "active"],
    [
        "Daredevil",
        "male",
        1964,
        "Enhanced senses, martial arts",
        "Defenders",
        "New York",
        8.7,
        "active",
    ],
    [
        "Doctor Strange",
        "male",
        1963,
        "Master of mystic arts",
        "Defenders",
        "New York",
        9.4,
        "active",
    ],
    [
        "Hank Pym",
        "male",
        1962,
        "Size manipulation",
        "Avengers",
        "New York",
        8.0,
        "retired",
    ],
    [
        "Scarlet Witch",
        "female",
        1964,
        "Reality manipulation",
        "Avengers",
        "Sokovia",
        9.3,
        "active",
    ],
    [
        "Wasp",
        "female",
        1963,
        "Size manipulation, flight",
        "Avengers",
        "New York",
        8.1,
        "active",
    ],
    [
        "Black Widow",
        "female",
        1964,
        "Expert spy, martial artist",
        "Avengers",
        "Russia",
        9.0,
        "deceased",
    ],
    [
        "Vision",
        "male",
        1968,
        "Density manipulation",
        "Avengers",
        "Synthoid",
        8.9,
        "active",
    ],
]

# %% [markdown]
# ---
# Create a `hero_df` pandas DataFrame with the given `hero_data`  with `col_names`

# %%
# your code goes here
hero_df = pd.DataFrame(data=hero_data, columns=col_names)
hero_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ---
# show its columns only

# %%
# your code goes here
hero_df.columns.to_list()
# Out:
# ['name',
#  'gender',
#  'first_appearance',
#  'superpower',
#  'team',
#  'origin',
#  'popularity_score',
#  'status']

# %% [markdown]
# ---
# show the row count of this dataframe

# %%
# your code goes here
hero_df.shape[0]
# Out:
# 20

# %% [markdown]
# ---
# set name column to be index of this dataframe

# %%
# your code goes here
hero_df = hero_df.set_index("name")
hero_df
# Out:
#                   gender  first_appearance  \
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968
#
# ...

# %% [markdown]
# ---
# Drop 'Namor' and 'Hank Pym' rows - do not save onto original. just show the result

# %%
# your code goes here
hero_df.drop(["Namor", "Hank Pym"])
# Out:
#                   gender  first_appearance  \
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968
#
#                                                    superpower            team  \
# name
# ...

# %% [markdown]
# ---
# Drop 'superpower' column - do not save onto original. just show the result

# %%
# your code goes here
hero_df.drop("superpower", axis=1)
# Out:
#                   gender  first_appearance            team        origin  \
# name
# Spider-Man          male              1962        Avengers      New York
# Captain America     male              1941        Avengers  World War II
# Wolverine           male              1974           X-Men        Canada
# Iron Man            male              1963        Avengers      New York
# Thor                male              1963        Avengers        Asgard
# Thing               male              1961  Fantastic Four      New York
# Mister Fantastic    male              1961  Fantastic Four      New York
# Hulk                male              1962        Avengers      New York
# Beast               male              1963           X-Men      Illinois
# Invisible Woman   female              1961  Fantastic Four      New York
# Storm             female              1975           X-Men         Kenya
# Namor               male              1939           X-Men      Atlantis
# ...

# %% [markdown]
# ---
# create copy of current dataframe of backup
#
# ```
# backup = hero_data.copy()

# %%
backup = hero_data.copy()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ---
# Show the first 4 rows on `hero_df`, but do not use `iloc` or `head`

# %%
# your code goes here
hero_df.loc["Spider-Man":"Iron Man"]
# Out:
#                 gender  first_appearance  \
# name
# Spider-Man        male              1962
# Captain America   male              1941
# Wolverine         male              1974
# Iron Man          male              1963
#
#                                             superpower      team  \
# name
# Spider-Man               Wall-crawling, super strength  Avengers
# Captain America                 Super soldier strength  Avengers
# Wolverine                          Regeneration, claws     X-Men
# Iron Man         Genius-level intellect, powered armor  Avengers
#
#                        origin  popularity_score    status
# name
# Spider-Man           New York               9.8    active
# Captain America  World War II               9.6    active
# Wolverine              Canada               9.5    active
# Iron Man             New York               9.7  deceased

# %% [markdown]
# ---
# Show the last 4 rows on `hero_df`, but do not use `iloc`

# %%
# your code goes here
hero_df.tail(4)
# Out:
#                gender  first_appearance                  superpower      team  \
# name
# Scarlet Witch  female              1964        Reality manipulation  Avengers
# Wasp           female              1963   Size manipulation, flight  Avengers
# Black Widow    female              1964  Expert spy, martial artist  Avengers
# Vision           male              1968        Density manipulation  Avengers
#
#                  origin  popularity_score    status
# name
# Scarlet Witch   Sokovia               9.3    active
# Wasp           New York               8.1    active
# Black Widow      Russia               9.0  deceased
# Vision         Synthoid               8.9    active

# %% [markdown]
# ---
# Show the last 3 columns on `hero_df` using iloc

# %%
# your code goes here
hero_df.iloc[:, -3:]
# Out:
#                         origin  popularity_score    status
# name
# Spider-Man            New York               9.8    active
# Captain America   World War II               9.6    active
# Wolverine               Canada               9.5    active
# Iron Man              New York               9.7  deceased
# Thor                    Asgard               9.8    active
# Thing                 New York               8.5    active
# Mister Fantastic      New York               8.8    active
# Hulk                  New York               9.2    active
# Beast                 Illinois               8.3    active
# Invisible Woman       New York               8.9    active
# Storm                    Kenya               9.1    active
# Namor                 Atlantis               7.9    active
# Hawkeye                   Iowa               7.8    active
# Daredevil             New York               8.7    active
# Doctor Strange        New York               9.4    active
# ...

# %% [markdown]
# ---
# Let's roll it back. Let's reset name to be column not index anymore

# %%
# your code goes here
hero_df = hero_df.reset_index()
hero_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ---
# Show just the `superpower` of the first 5 elements on `hero_df`
# - make sure you are printing it as DATAFRAME

# %%
# your code goes here
hero_df["superpower"][:5].to_frame()
# Out:
#                               superpower
# 0          Wall-crawling, super strength
# 1                 Super soldier strength
# 2                    Regeneration, claws
# 3  Genius-level intellect, powered armor
# 4                Godly strength, Mjölnir

# %% [markdown]
# ---
# Show the first and last rows, and first and last columns on `hero_df`

# %%
# your code goes here
hero_df.iloc[[0, -1], [0, -1]]
# Out:
#           name  status
# 0   Spider-Man  active
# 19      Vision  active

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ---
# Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here
hero_df.loc[hero_df["name"] == "Vision", "first_appearance"] = 1964
hero_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ---
# Add a new column to `hero_df` called `years_since` with the years since `first_appearance`

# %%
# your code goes here
hero_df["years_since"] = 2025 - hero_df["first_appearance"] + 1
hero_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ---
# Given the `hero_df` pandas DataFrame, make a mask showing the female characters - just show mask

# %%
# your code goes here
hero_df["gender"] == "female"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19    False
# Name: gender, dtype: bool

# %% [markdown]
# ---
# Given the `hero_df` pandas DataFrame, get the characters with `first_appearance` after 1970 - show filtered result

# %%
# your code goes here
hero_df[hero_df["first_appearance"] > 1970]
# Out:
#          name  gender  first_appearance            superpower   team  origin  \
# 2   Wolverine    male              1974   Regeneration, claws  X-Men  Canada
# 10      Storm  female              1975  Weather manipulation  X-Men   Kenya
#
#     popularity_score  status  years_since
# 2                9.5  active           52
# 10               9.1  active           51

# %% [markdown]
# ---
# Given the `hero_df` pandas DataFrame, get the characters with `first_appearance` is NOT 1961 - show filtered result

# %%
# your code goes here
hero_df[hero_df["first_appearance"] != 1961]
# Out:
#                name  gender  first_appearance  \
# 0        Spider-Man    male              1962
# 1   Captain America    male              1941
# 2         Wolverine    male              1974
# 3          Iron Man    male              1963
# 4              Thor    male              1963
# 7              Hulk    male              1962
# 8             Beast    male              1963
# 10            Storm  female              1975
# 11            Namor    male              1939
# 12          Hawkeye    male              1964
# 13        Daredevil    male              1964
# 14   Doctor Strange    male              1963
# 15         Hank Pym    male              1962
# 16    Scarlet Witch  female              1964
# 17             Wasp  female              1963
# 18      Black Widow  female              1964
# 19           Vision    male              1964
#
#                                      superpower       team        origin  \
# ...

# %% [markdown]
# ---
# Given the `hero_df` pandas DataFrame, get the characters in team `Avengers` whose status is NOT `active` show filtered result

# %%
c1 = hero_df["team"] == "Avengers"
c2 = hero_df["status"] != "active"
hero_df[c1 & c2]
# Out:
#            name  gender  first_appearance  \
# 3      Iron Man    male              1963
# 15     Hank Pym    male              1962
# 18  Black Widow  female              1964
#
#                                superpower      team    origin  \
# 3   Genius-level intellect, powered armor  Avengers  New York
# 15                      Size manipulation  Avengers  New York
# 18             Expert spy, martial artist  Avengers    Russia
#
#     popularity_score    status  years_since
# 3                9.7  deceased           63
# 15               8.0   retired           64
# 18               9.0  deceased           62

# %% [markdown]
# ---
# Convert a gender column to have 'M' and 'F' instead of 'male' and 'female'
# - use replace

# %%
# your code goes here
hero_df["gender"] = hero_df["gender"].replace({"male": "M", "female": "F"})
hero_df
# Out:
#                 name gender  first_appearance  \
# 0         Spider-Man      M              1962
# 1    Captain America      M              1941
# 2          Wolverine      M              1974
# 3           Iron Man      M              1963
# 4               Thor      M              1963
# 5              Thing      M              1961
# 6   Mister Fantastic      M              1961
# 7               Hulk      M              1962
# 8              Beast      M              1963
# 9    Invisible Woman      F              1961
# 10             Storm      F              1975
# 11             Namor      M              1939
# 12           Hawkeye      M              1964
# 13         Daredevil      M              1964
# 14    Doctor Strange      M              1963
# 15          Hank Pym      M              1962
# 16     Scarlet Witch      F              1964
# 17              Wasp      F              1963
# 18       Black Widow      F              1964
# ...

# %% [markdown]
# ---
# Let's roll it back. Convert a gender column to have 'male' and 'female'
# - use lambda function

# %%
hero_df["gender"] = hero_df["gender"].map(lambda x: "male" if x == "M" else "female")
hero_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ---
# Show basic statistics summary of `hero_df`

# %%
# your code goes here
hero_df.describe()
# Out:
#        first_appearance  popularity_score  years_since
# count         20.000000         20.000000    20.000000
# mean        1961.650000          8.915000    64.350000
# std            8.298859          0.644225     8.298859
# min         1939.000000          7.800000    51.000000
# 25%         1961.750000          8.450000    62.000000
# 50%         1963.000000          8.950000    63.000000
# 75%         1964.000000          9.425000    64.250000
# max         1975.000000          9.800000    87.000000

# %% [markdown]
# ---
# Given the `hero_df` pandas DataFrame, show each count of character's origin
# - you will know how many people are from New york, Asgard, Iowa etc

# %%
# your code goes here
hero_df["origin"].value_counts()
# Out:
# origin
# New York        10
# World War II     1
# Canada           1
# Asgard           1
# Illinois         1
# Kenya            1
# Atlantis         1
# Iowa             1
# Sokovia          1
# Russia           1
# Synthoid         1
# Name: count, dtype: int64

# %% [markdown]
# ---
# Given the `hero_df` pandas DataFrame, show the minimum and mean value of `years_since`

# %%
# your code goes here

# %%
# your code goes here
hero_df["years_since"].min(), hero_df["years_since"].mean().round(2)
# Out:
# (np.int64(51), np.float64(64.35))

# %% [markdown]
# ---
# Given the `hero_df` pandas DataFrame, consider the conditions.
# - first_appearance is before 1969(not including 1969)
# - male
# - team name not Fantastic Four
#
# And find:
# - find how many characters are qualified
# - find their average of popularity score

# %%
# your code goes here
c1 = hero_df["first_appearance"] < 1969
c2 = hero_df["gender"] == "male"
c3 = hero_df["team"] != "Fantastic Four"

ans = hero_df.loc[c1 & c2 & c3]
ans
# Out:
#                name gender  first_appearance  \
# 0        Spider-Man   male              1962
# 1   Captain America   male              1941
# 3          Iron Man   male              1963
# 4              Thor   male              1963
# 7              Hulk   male              1962
# 8             Beast   male              1963
# 11            Namor   male              1939
# 12          Hawkeye   male              1964
# 13        Daredevil   male              1964
# 14   Doctor Strange   male              1963
# 15         Hank Pym   male              1962
# 19           Vision   male              1964
#
#                                      superpower       team        origin  \
# 0                 Wall-crawling, super strength   Avengers      New York
# 1                        Super soldier strength   Avengers  World War II
# 3         Genius-level intellect, powered armor   Avengers      New York
# 4                       Godly strength, Mjölnir   Avengers        Asgard
# ...

# %%
print(ans.shape[0])
print(ans["popularity_score"].mean().round(2))
# Out:
# 12
# 8.93

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ---
# Bar-Plot the value count of `first_appearance`
# - your plot must show there are 5 characters in 1963, 3 characters in 1962 etc
# - plot in ascending order!

# %%
# your code goes here
hero_df["first_appearance"].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='first_appearance'>

# %% [markdown]
# ---
# Bar-Plot the value count of `team`
# - your plot must show there are 11 Avengers, 4 X-men etc

# %%
# your code goes here
hero_df["team"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='team'>

# %% [markdown]
# ---
# Histogram of members' `popularity_score`

# %%
hero_df["popularity_score"].plot(kind="hist", bins=5)
# Out:
# <Axes: ylabel='Frequency'>
